# %% [markdown]
# ## ENV

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:78% !important; }</style>"))
# Out:
# <style>.container { width:78% !important; }</style>

# %% [markdown]
# ## 파이썬 다운로드 페이지 접속

# %% [markdown]
# * python.ogr 접속: https://www.python.org/
# * Downloads >> Windows 선택

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# ## 파이썬 다운로드

# %% [markdown]
# * 3.7.7 버전 executable installer를 다운

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 파이썬 설치 프로그램 실행

# %% [markdown]
# * 다운로드 받은 설치 프로그램을 실행
# * 설치되는 과정에서 프로그램이 설치되는 폴더를 기억

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 설치 진행

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 설치 완료

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 파이썬 실행경로 등록

# %% [markdown]
# * 설치할 때 기억해 두었던 파이썬의 설치 경로를 환경변수로 등록
# * 아래와 같이 고급 시스템 설정을 선택

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 아래와 같이 하단의 '환경변수' 선택

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 아래와 같이 사용자 변수 혹은 시스템 변수로 등록 편집을 선택

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 아래와 같이 환경변수로 경로를 추가하여 등록

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 파이썬 실행

# %% [markdown]
# * 윈도우키 + R : 명령창에서 cmd 입력하고 확인
# * 아래와 같은 command 입력창이 뜨는 것을 확인
# * 명령행에 python 을 입력하고 enter
# * 아래와 같이 뜨는 것이 확인되면 정상 설치

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## pip 설치

# %% [markdown]
# * 아래의 명령어를 실행하여 pip 설치를 위한 get-pip.py 다운로드
#     * curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# * 혹은 아래 링크에서 우클릭으로 다른이름 저장하여 다운로드
#     * https://bootstrap.pypa.io/get-pip.py
# * 다운로드한 파일을 아래의 명령어로 실행
#     * python get-pip.py
# * pip 이 설치되면 필요한 패키지를 pip install [패키지명] 으로 자동 설치할 수 있음

# %% [markdown]
# ## jupyter notebook 설치와 실행

# %% [markdown]
# * pip 명령어로 jupyter 설치
#     * pip install jupyter
# * 설치가 완료되면 아래의 명령어로 jupyter 실행
#     * jupyter notebook
